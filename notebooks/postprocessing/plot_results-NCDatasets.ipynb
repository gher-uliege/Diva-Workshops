# %% [markdown]
# This notebook describes how to create plots for the netCDF file(s) obtained after executing `DIVAnd`.
# We will use the [NCDatasets](https://github.com/Alexander-Barth/NCDatasets.jl) module (instead of [NetCDF](https://github.com/JuliaGeo/NetCDF.jl)) to read the result files and [PyPlot](https://github.com/JuliaPy/PyPlot.jl).

# %%
using NCDatasets  
using PyPlot

# %% [markdown]
# Adapt the file directory and name.
# We can use for example the salinity analysis produced by [15-example-analysis](./15-example-analysis.ipynb).

# %%
datadir = "./"
datafile = joinpath(datadir, "Water_body_Salinity.4Danl.nc")
if isfile(datafile)
    info("File exist") 
else
    error("File does not exist")
end
# Out:
# 02-avril 21:56:41:INFO:root:File exist

# %% [markdown]
# Open the dataset from the file for reading

# %%
info("Reading dataset")
ds = Dataset(datafile)
# Out:
# 02-avril 21:56:44:INFO:root:Reading dataset
# Dataset: ./Water_body_Salinity.4Danl.nc
# Group: /
#
# Dimensions
#    lon = 76
#    lat = 36
#    depth = 3
#    time = 8
#    nv = 2
#
# Variables
#   lon   (76)
#     Datatype:    Float64
#     Dimensions:  lon
#     Attributes:
#      units                = degrees_east
#      standard_name        = longitude
#      long_name            = longitude
#
#   lat   (36)
#     Datatype:    Float64
#     Dimensions:  lat
#     Attributes:
#      units                = degrees_north
#      standard_name        = latitude
#      long_name            = latitude
#
#   depth   (3)
#     Datatype:    Float64
#     Dimensions:  depth
#     Attributes:
#      units                = meters
#      positive             = down
#      standard_name        = depth
#      long_name            = depth below sea level
#
#   time   (8)
#     Datatype:    Float64
#     Dimensions:  time
#     Attributes:
#      units                = days since 1900-01-01 00:00:00
#      standard_name        = time
#      long_name            = time
#      calendar             = standard
#
#   Salinity   (76 × 36 × 3 × 8)
#     Datatype:    Float32
#     Dimensions:  lon × lat × depth × time
#     Attributes:
#      units                = 1e-3
#      standard_name        = sea_water_salinity
#      long_name            = sea water salinity
#      _FillValue           = 9.96921e36
#      missing_value        = 9.96921e36
#      cell_methods         = time: mean within years time: mean over years
#
#   Salinity_L1   (76 × 36 × 3 × 8)
#     Datatype:    Float32
#     Dimensions:  lon × lat × depth × time
#     Attributes:
#      units                = 1e-3
#      standard_name        = sea_water_salinity
#      long_name            = sea water salinity masked using relative error threshold 0.3
#      _FillValue           = 9.96921e36
#      missing_value        = 9.96921e36
#
#   Salinity_L2   (76 × 36 × 3 × 8)
#     Datatype:    Float32
#     Dimensions:  lon × lat × depth × time
#     Attributes:
#      units                = 1e-3
#      standard_name        = sea_water_salinity
#      long_name            = sea water salinity masked using relative error threshold 0.5
#      _FillValue           = 9.96921e36
#      missing_value        = 9.96921e36
#
#   Salinity_relerr   (76 × 36 × 3 × 8)
#     Datatype:    Float32
#     Dimensions:  lon × lat × depth × time
#     Attributes:
#      units                = 1
#      long_name            = Relative error of sea water salinity
#      valid_min            = 0.0
#      valid_max            = 1.0
#      _FillValue           = 9.96921e36
#      missing_value        = 9.96921e36
#
# Global attributes
#   Conventions          = CF-1.6
#   title                = DIVA 4D analysis of sea water salinity
#   file_name            = Water_body_Salinity.4Danl.nc
#   product_id           = f0b6c078-17be-11e8-34b7-0bf0e507511d
#   date                 = 2018-02-22T11:55:48
#   project              = SeaDataCloud
#   institution          = University of Liege, GeoHydrodynamics and Environment Research
#   institution_urn      = SDN:EDMO::1579
#   production           = Diva group. E-mails: a.barth@ulg.ac.be, swatelet@ulg.ac.be
#   Author_e-mail        = Your Name1 <name1@example.com>, Other Name <name2@example.com>
#   source               = observational data from SeaDataNet/EMODNet Chemistry Data Network
#   comment              = ...
#   parameter_keyword    = Water body salinity
#   parameter_keyword_urn = SDN:P35::EPC00001
#   search_keywords      = Salinity of the water column
#   search_keywords_urn  = SDN:P02::PSAL
#   area_keywords        = Black Sea
#   area_keywords_urn    = SDN:C19::3_3
#   product_code         = ULg-GHER-Black Sea-Water body salinity-1.0-ANA
#   product_version      = 1.0
#   abstract             = ...
#   acknowledgment       = ...
#   doi                  = ...
#   data_access          = http://sdn.oceanbrowser.net/data/SeaDataCloud-domains
#   WEB_visualisation    = http://sdn.oceanbrowser.net/web-vis/

# %% [markdown]
# From the dataset we can extract the dimensions and variables of interest.

# %%
lon = ds["lon"];
lat = ds["lat"];
depth = ds["depth"];
ttime = ds["time"];
salinity = ds["Salinity"];

# %% [markdown]
# Note that the time variable is an array of dates:

# %%
ttime
# Out:
# 8-element NCDatasets.CFVariable{Float64,Float64,1}:
#  1993-02-16T00:00:00
#  1993-05-16T00:00:00
#  1993-08-16T00:00:00
#  1993-11-16T00:00:00
#  1994-02-16T00:00:00
#  1994-05-16T00:00:00
#  1994-08-16T00:00:00
#  1994-11-16T00:00:00

# %% [markdown]
# # Create plots
# ## Simple pseudo color plot
# Let's assume we want to plot a given time period at a given depth:

# %%
depthplot = 20.;

# %% [markdown]
# First we extract the indices of the the time and depth arrays.

# %%
timeindex = 4;
depthindex = find(depth .== depthplot)[1];
info("Time index: $timeindex")
info("Depth index: $depthindex")
# Out:
# 02-avril 21:57:44:INFO:root:Time index: 4
# 02-avril 21:57:44:INFO:root:Depth index: 2

# %% [markdown]
# Then we extract the 2-D salinity field. If we are not sure about the dimension order, we can check the matrix size.

# %%
@show size(salinity);
salinityplot = salinity[:, :, depthindex, timeindex];
@show size(salinityplot);
salinityplot = salinityplot.data;
# Out:
# size(salinity) = (76, 36, 3, 8)
# size(salinityplot) = (76, 36)

# %% [markdown]
# ### First plot
# We use the `pcolormesh` (pseudo-color) function:

# %%
pcolormesh(lon, lat, transpose(salinityplot))
colorbar()
show()
# Out:
# PyPlot.Figure(PyObject <Figure size 1920x1440 with 2 Axes>)

# %% [markdown]
# ### Masking landObviously the land-sea mask was not taken into account in the previous figure.
# We replace the *fill value* by NaN:

# %%
fill_value = salinity.attrib["_FillValue"]
salinityplot[salinityplot .== fill_value] = NaN;
@show fill_value;
# Out:
# fill_value = 9.96921f36

# %%
pcolormesh(lon, lat, transpose(salinityplot));
colorbar()
# Out:
# PyPlot.Figure(PyObject <Figure size 1920x1440 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7f51347beb50>

# %% [markdown]
# ## Contour plots
# We explicitely specify the levels to be represented (from 15 to 25).

# %%
conts = contour(lon, lat, transpose(salinityplot), levels=collect(15:.25:25))
clabel(conts, inline=1, fontsize=10);
# Out:
# PyPlot.Figure(PyObject <Figure size 1920x1440 with 1 Axes>)

# %% [markdown]
# ## Filled contour plots
# The aspect is somehow different from the pcolor.

# %%
contourf(lon, lat, transpose(salinityplot), levels=collect(15:1:25))
# Out:
# PyPlot.Figure(PyObject <Figure size 1920x1440 with 1 Axes>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7f5134404090>
