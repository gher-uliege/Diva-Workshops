# %% [markdown]
# # Example of detrending and geostrophic flow calculation

# %%
using DIVAnd
using Dates
using Statistics
using Makie, CairoMakie, GeoMakie
using PhysOcean
using NCDatasets
using DataStructures
using Pkg
include("../config.jl")
# Load a more efficient version of sparse matrix multiplication
include(joinpath(dirname(pathof(DIVAnd)),"override_ssmult.jl"))

# %%
Pkg.status()
# Out:
# Status `~/Projects/Diva-Workshops/Project.toml`
#   [336ed68f] CSV v0.10.15
# ⌃ [13f3f980] CairoMakie v0.12.16
#   [35d6a980] ColorSchemes v3.27.1
#   [34da2185] Compat v4.16.0
#   [efc8151c] DIVAnd v2.7.12
#   [864edb3b] DataStructures v0.18.20
#   [8bb1440f] DelimitedFiles v1.9.1
#   [b16dfd50] GRIB v0.4.0 `https://github.com/weech/GRIB.jl#master`
# ⌃ [2fb1d81b] GeoArrays v0.9.0
#   [61d90e0f] GeoJSON v0.8.1
#   [db073c08] GeoMakie v0.7.9
#   [7073ff75] IJulia v1.26.0
#   [a98d9a8b] Interpolations v0.15.1
#   [23992714] MAT v0.10.7
# ⌅ [ee78f7c6] Makie v0.21.16
#   [e1d29d7a] Missings v1.2.0
#   [85f8d34a] NCDatasets v0.14.6
#   [3725be50] PhysOcean v0.6.11 `https://github.com/gher-uliege/PhysOcean.jl.git#master`
#   [d330b81b] PyPlot v2.11.5
#   [f2b01f46] Roots v2.2.2
#   [10745b16] Statistics v1.11.1
#   [8d837e6f] TIFFDatasets v0.1.1
#   [3d5dd08c] VectorizationBase v0.21.71
#   [ade2ca70] Dates v1.11.0
#   [37e2e46d] LinearAlgebra v1.11.0
#   [56ddb016] Logging v1.11.0
#   [44cfe95a] Pkg v1.11.0
#   [de0858da] Printf v1.11.0
#   [9a3f8284] Random v1.11.0
#   [8dfed614] Test v1.11.0
# Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated`
# Warning The project dependencies or compat requirements have changed since the manifest was last resolved. It is recommended to `Pkg.resolve()` or consider `Pkg.update()` if necessary.

# %% [markdown]
# ## Bathmetry reading

# %%
bathname = gebco08file
download_check(gebco08file, gebco08fileURL)
bathisglobal = true;
# Out:
# [ Info: File already downloaded

# %% [markdown]
# ## Bathymetry and grid preparation

# %%
dx = dy = 0.125

lonr = 27:dx:42
latr = 40:dy:47
depthr = [0., 5., 10, 15., 20, 25., 30, 40, 50, 60, 75, 85, 100, 125, 150, 
    200, 250, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1750, 2000];

sz = (length(lonr),length(latr),length(depthr))

# correlation length in meters (in x, y, and z directions)

epsilon2=1
lenx = [2.5+depthr[k]/1000 for i = 1:sz[1], j = 1:sz[2], k = 1:sz[3]]
leny = [1.5+depthr[k]/1000 for i = 1:sz[1], j = 1:sz[2], k = 1:sz[3]]
lenz = [5+(depthr[min(k+1,sz[3])]-depthr[max(1,k-1)]) for i = 1:sz[1], j = 1:sz[2], k = 1:sz[3]]

mask,(pm,pn,po),(xi,yi,zi) = DIVAnd.DIVAnd_rectdom(lonr,latr,depthr)
bx,by,b = DIVAnd.load_bath(bathname,true,lonr,latr)
mask = falses(size(b,1),size(b,2),size(depthr,1))


for j = 1:size(b,2)
    for i = 1:size(b,1)
        for k=1:size(depthr,1)
            mask[i,j,k] = b[i,j] >=zi[i,j,k]
        end
    end
end

# %% [markdown]
# Look at topology

# %%
plot_mask(bx, by, mask[:,:,end], xticks=24.:3.:45, yticks=40:1.:47.)

# %% [markdown]
# Take out Marmara and Azov sea

# %%
sel1= (xi.>34.75) .& (yi.>45.10)
mask[sel1].=false
sel1= (xi.<29.5) .& (yi.<41.125)
mask[sel1].=false

plot_mask(bx, by, mask[:,:,1], depth=0)

# %% [markdown]
# ## Load data

# %%
datafile = salinitybigfile
download_check(salinitybigfile, salinitybigfileURL)
value,lon,lat,depth,timeval,ids = DIVAnd.loadbigfile(datafile)
@show size(value)
# Out:
# [ Info: File already downloaded
# [ Info: Loading data from 'big file' ../data/Salinity.bigfile
# size(value) = (139230,)
# (139230,)

# %%
deepestdata=5500.0
lowestdata=14.0
highestdata=25.0
# Out:
# 25.0

# %% [markdown]
# ### Subset data
# Taking out Marmara and Azov sea

# %%
sel=(value.>lowestdata) .& (value.<highestdata).& .~((lon.>34.75) .& (lat.>45.10)) .& 
.~((lon.<29.5) .& (lat.<41.125)) .& (depth.<deepestdata) .& (timeval .> DateTime(Date(1950)))

fig = Figure(size=(900, 400))
ax1 = Axis(fig[1,1], title="Original dataset")
sc1 = scatter!(ax1, lon, lat, color=value, markersize=2, colorrange=[lowestdata,highestdata])
Colorbar(fig[2,1], sc1, vertical=false)

# Perform subsetting
value=value[sel]
lon=lon[sel]
lat=lat[sel]
depth=depth[sel]
timeval=timeval[sel]
ids=ids[sel]

@show(size(value))

ax2 = Axis(fig[1,2], title="With data subsetting")
sc2 = scatter!(ax2, lon, lat, color=value, markersize=2, colorrange=[lowestdata,highestdata])
Colorbar(fig[2,2], sc2, vertical=false)
display(fig)
# Out:
# size(value) = (136854,)
# CairoMakie.Screen{IMAGE}

# %% [markdown]
# ### Observational error variance inflation factor

# %%
rdiag=1.0./DIVAnd.weight_RtimesOne((lon,lat,depth),(0.03,0.03,10));
mean(rdiag)
# Out:
# [ Info: Computing weights using 1 CPU thread(s)
# 12.07981627420008

# %% [markdown]
# ### Useful functions to define new coordinates

# %%
function dayinyear(x); return Dates.value(Date(x)-Date(Dates.year(x))); end
function daysince1900(x); return Dates.value(Date(x)-Date(Dates.year(DateTime(1900)))); end
# Out:
# daysince1900 (generic function with 1 method)

# %% [markdown]
# ### Prepare a new analysis space:
# - depth,
# - day-in-a-year,
# - time-in-days-from-1900

# %%
coordinatesfordetrending=(depth,dayinyear.(timeval),daysince1900.(timeval));
tmin,tmax=extrema(daysince1900.(timeval))
maskt,(pmt,pnt,pot),(xit,yit,zit) = DIVAnd.DIVAnd_rectdom(depthr,0:10:365,tmin:150:tmax);

# %%
sz=size(maskt)
lent3 = [15000+10*depthr[i] for i = 1:sz[1], j = 1:sz[2], k = 1:sz[3]]
lent2 = [150+depthr[i]/20 for i = 1:sz[1], j = 1:sz[2], k = 1:sz[3]]
lent1 = [5+(depthr[min(i+1,sz[1])]-depthr[max(1,i-1)]) for i = 1:sz[1], j = 1:sz[2], k = 1:sz[3]];

# %% [markdown]
# Two user functions defining the two scales. One is the trend analysis, the other the normal analysis.

# %%
function H1K1(data)
    K1d,s=DIVAnd.DIVAndrun(maskt,(pmt,pnt,pot),(xit,yit,zit),coordinatesfordetrending,data,(lent1,lent2,lent3),epsilon2*rdiag;moddim=[0,365,0]);
    #K1d,s=DIVAndrun(mask[1],pm[1],xi[1],x,data,len[1],epsilon2)    
    return K1d,data.-DIVAnd_residual(s,K1d)
end
function H2K2(data)
    K2d,s=DIVAnd.DIVAndrun(mask,(pm,pn,po),(xi,yi,zi),(lon,lat,depth),data,(lenx,leny,lenz),epsilon2*rdiag);
    #K1d,s=DIVAndrun(mask[1],pm[1],xi[1],x,data,len[1],epsilon2)    
    return K2d,data.-DIVAnd_residual(s,K2d)
end
# Out:
# H2K2 (generic function with 1 method)

# %% [markdown]
# Simple analysis for the trend space

# %%
fdet,bidon=H1K1(value .- mean(value));
# Out:
# MethodError: no method matching spmatmul(::SparseMatrixCSC{Float64, Int64}, ::SparseMatrixCSC{Float64, Int64}; sortindices::Symbol)
# This method may not support any kwargs.
#
# Closest candidates are:
#   spmatmul(::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer}), LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}}, UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}}} where {Tv, Ti}, ::Union{SubArray{<:Any, <:Any, <:AbstractSparseArray}, LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}} where {Tv, Ti}, UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}} where {Tv, Ti}, SparseArrays.AbstractCompressedVector, SparseArrays.AbstractSparseMatrixCSC{Tv, Ti} where {Tv, Ti}}) got unsupported keyword argument "sortindices"
#    @ SparseArrays ~/.julia/juliaup/julia-1.11.2+0.x64.linux.gnu/share/julia/stdlib/v1.11/SparseArrays/src/linalg.jl:215
#
#
# Stacktrace:
#   [1] *(A::SparseMatrixCSC{Float64, Int64}, B::Adjoint{Float64, SparseMatrixCSC{Float64, Int64}})
#     @ Main ~/.julia/packages/DIVAnd/4UymR/src/override_ssmult.jl:5
#   [2] DIVAnd_laplacian(operatortype::Type, mask::BitArray{3}, pmn::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, nu::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, iscyclic::BitVector; coeff_laplacian::Vector{Float64})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_laplacian.jl:97
#   [3] DIVAnd_laplacian
#     @ ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_laplacian.jl:49 [inlined]
#   [4] DIVAnd_operators(operatortype::Type, mask::BitArray{3}, pmn::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, nu::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, iscyclic::BitVector, mapindex::Vector{Any}, Labs::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}; coeff_laplacian::Vector{Float64})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_operators.jl:59
#   [5] DIVAnd_background(operatortype::Type, mask::BitArray{3}, pmn::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, Labs::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, alpha::Vector{Any}, moddim::Vector{Int64}, scale_len::Bool, mapindex::Vector{Any}; btrunc::Vector{Any}, coeff_laplacian::Vector{Float64}, coeff_derivative2::Vector{Float64}, mean_Labs::Nothing)
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_background.jl:94
#   [6] DIVAnd_background
#     @ ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_background.jl:20 [inlined]
#   [7] DIVAndrun(operatortype::Type, mask::BitArray{3}, pmnin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, xiin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, x::Tuple{Vector{Float64}, Vector{Int64}, Vector{Int64}}, f::Vector{Float64}, lin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, epsilon2::Vector{Float64}; velocity::Tuple{}, primal::Bool, factorize::Bool, tol::Float64, maxit::Int64, minit::Int64, constraints::Tuple{}, ineqconstraints::Tuple{}, ntriesmax::Int64, inversion::Symbol, moddim::Vector{Int64}, fracindex::Matrix{Float64}, alpha::Vector{Any}, keepLanczosVectors::Int64, compPC::typeof(DIVAnd_pc_none), progress::DIVAnd.var"#289#293", fi0::Array{Float64, 3}, f0::Vector{Float64}, alphabc::Float64, scale_len::Bool, btrunc::Vector{Any}, MEMTOFIT::Float64, topographyforfluxes::Tuple{}, fluxes::Tuple{}, epsfluxes::Int64, epsilon2forfractions::Int64, RTIMESONESCALES::Tuple{}, QCMETHOD::Tuple{}, coeff_laplacian::Vector{Float64}, coeff_derivative2::Vector{Float64}, mean_Labs::Nothing)
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAndrun.jl:154
#   [8] DIVAndrun(mask::BitArray{3}, pmnin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, xiin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, x::Tuple{Vector{Float64}, Vector{Int64}, Vector{Int64}}, f::Vector{Float64}, lin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, epsilon2::Vector{Float64}; operatortype::Type, kwargs::@Kwargs{moddim::Vector{Int64}})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAndrun.jl:401
#   [9] H1K1(data::Vector{Float64})
#     @ Main ./In[13]:2
#  [10] top-level scope
#     @ In[14]:1

# %%
pcolor(yit[1,:,:],zit[1,:,:],mean(value)+fdet[1,:,:]),colorbar()
figure()
scatter(coordinatesfordetrending[2],coordinatesfordetrending[3],s=2,c=value,vmin=17,vmax=18.4);colorbar()
# Out:
# UndefVarError: `pcolor` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[15]:1

# %% [markdown]
# Simple surface analysis

# %%
fsur,bidon=H2K2(value.-mean(value))
fsurori=fsur;

figure()
pcolor(xi[:,:,1],yi[:,:,1],mean(value)+fsur[:,:,1]),colorbar()
figure()
scatter(lon,lat,s=2,c=value,vmin=17,vmax=18.4);colorbar()
# Out:
# MethodError: no method matching spmatmul(::SparseMatrixCSC{Float64, Int64}, ::SparseMatrixCSC{Float64, Int64}; sortindices::Symbol)
# This method may not support any kwargs.
#
# Closest candidates are:
#   spmatmul(::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer}), LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}}, UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}}} where {Tv, Ti}, ::Union{SubArray{<:Any, <:Any, <:AbstractSparseArray}, LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}} where {Tv, Ti}, UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:(AbstractUnitRange{<:Integer})}} where {Tv, Ti}, SparseArrays.AbstractCompressedVector, SparseArrays.AbstractSparseMatrixCSC{Tv, Ti} where {Tv, Ti}}) got unsupported keyword argument "sortindices"
#    @ SparseArrays ~/.julia/juliaup/julia-1.11.2+0.x64.linux.gnu/share/julia/stdlib/v1.11/SparseArrays/src/linalg.jl:215
#
#
# Stacktrace:
#   [1] *(A::SparseMatrixCSC{Float64, Int64}, B::Adjoint{Float64, SparseMatrixCSC{Float64, Int64}})
#     @ Main ~/.julia/packages/DIVAnd/4UymR/src/override_ssmult.jl:5
#   [2] DIVAnd_laplacian(operatortype::Type, mask::BitArray{3}, pmn::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, nu::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, iscyclic::BitVector; coeff_laplacian::Vector{Float64})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_laplacian.jl:97
#   [3] DIVAnd_laplacian
#     @ ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_laplacian.jl:49 [inlined]
#   [4] DIVAnd_operators(operatortype::Type, mask::BitArray{3}, pmn::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, nu::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, iscyclic::BitVector, mapindex::Vector{Any}, Labs::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}; coeff_laplacian::Vector{Float64})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_operators.jl:59
#   [5] DIVAnd_background(operatortype::Type, mask::BitArray{3}, pmn::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, Labs::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, alpha::Vector{Any}, moddim::Vector{Any}, scale_len::Bool, mapindex::Vector{Any}; btrunc::Vector{Any}, coeff_laplacian::Vector{Float64}, coeff_derivative2::Vector{Float64}, mean_Labs::Nothing)
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_background.jl:94
#   [6] DIVAnd_background
#     @ ~/.julia/packages/DIVAnd/4UymR/src/DIVAnd_background.jl:20 [inlined]
#   [7] DIVAndrun(operatortype::Type, mask::BitArray{3}, pmnin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, xiin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, x::Tuple{Vector{Float64}, Vector{Float64}, Vector{Float64}}, f::Vector{Float64}, lin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, epsilon2::Vector{Float64}; velocity::Tuple{}, primal::Bool, factorize::Bool, tol::Float64, maxit::Int64, minit::Int64, constraints::Tuple{}, ineqconstraints::Tuple{}, ntriesmax::Int64, inversion::Symbol, moddim::Vector{Any}, fracindex::Matrix{Float64}, alpha::Vector{Any}, keepLanczosVectors::Int64, compPC::typeof(DIVAnd_pc_none), progress::DIVAnd.var"#288#292", fi0::Array{Float64, 3}, f0::Vector{Float64}, alphabc::Float64, scale_len::Bool, btrunc::Vector{Any}, MEMTOFIT::Float64, topographyforfluxes::Tuple{}, fluxes::Tuple{}, epsfluxes::Int64, epsilon2forfractions::Int64, RTIMESONESCALES::Tuple{}, QCMETHOD::Tuple{}, coeff_laplacian::Vector{Float64}, coeff_derivative2::Vector{Float64}, mean_Labs::Nothing)
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAndrun.jl:154
#   [8] DIVAndrun(operatortype::Type, mask::BitArray{3}, pmnin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, xiin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, x::Tuple{Vector{Float64}, Vector{Float64}, Vector{Float64}}, f::Vector{Float64}, lin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, epsilon2::Vector{Float64})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAndrun.jl:2
#   [9] DIVAndrun(mask::BitArray{3}, pmnin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, xiin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, x::Tuple{Vector{Float64}, Vector{Float64}, Vector{Float64}}, f::Vector{Float64}, lin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, epsilon2::Vector{Float64}; operatortype::Type, kwargs::@Kwargs{})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAndrun.jl:401
#  [10] DIVAndrun(mask::BitArray{3}, pmnin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, xiin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, x::Tuple{Vector{Float64}, Vector{Float64}, Vector{Float64}}, f::Vector{Float64}, lin::Tuple{Array{Float64, 3}, Array{Float64, 3}, Array{Float64, 3}}, epsilon2::Vector{Float64})
#     @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/DIVAndrun.jl:389
#  [11] H2K2(data::Vector{Float64})
#     @ Main ./In[13]:7
#  [12] top-level scope
#     @ In[45]:1

# %% [markdown]
# ## Now detrending via scale separation

# %%
?scaleseparation
# Out:
# search: scaleseparation
#   Phi1,H1Phi1,Phi2,H2Phi2=scaleseparation(K1andH1K1,K2andH2K2,d;niter=10)
#
#   Input:
#   ≡≡≡≡≡≡
#
#     •  K1andH1K1 : function, when called with a vector of data d,
#        provides in return Kd,HK d ; i.e. the gridded analysis Kd and
#        analysis HKd at data points for analysis tool 1
#
#     •  K2andH2K2 : function, when called with a vector of data d,
#        provides in return Kd,HK d ; i.e. the gridded analysis Kd and
#        analysis HKd at data points for analysis tool 2
#
#     •  d : data array
#
#     •  niter= : optional keyword parameter defining the number of
#        iterations used to invert I - H2K2 H1K2. Default is 10
#
#   Output:
#   ≡≡≡≡≡≡≡
#
#     •  Phi1 : analysis for tool 1 in which analysis of scale 2 is taken
#        out
#
#     •  H1Phi1 : analysis at data locations for tool 1 in which analysis
#        of scale 2 is taken out
#
#     •  Phi2 : analysis for tool 2 in which analysis of scale 1 is taken
#        out
#
#     •  H2Phi2 : analysis at data locations for tool 2 in which analysis
#        of scale 1 is taken out
#
#   Tool to separate scales using two different analysis provided as two input
#   functions
#
#   K1 should be related to the larger scales (or scales with high signal/noise
#   ratios) and K2 to smaller or less energetic scales. If in doubt invert both
#   and test with different number of iterations while looking at convergence.
#
#   see "Multi-scale optimal interpolation: application to DINEOF analysis
#   spiced with a local optimal interpolation" http://hdl.handle.net/2268/165394
#
#   Here the two fields can have different supports (one could be a 3D analysis
#   and the other one a season-depth analysis for example. Only the
#   observational operators must provide the same data array at the output. In
#   other words K1,HK1=K1andH1K1 should provide an output array HK1 of the same
#   dimensions as the data array d and the output HK2 from K2,HK2=K2andH2K2

# %%
fdet,dd1,fsur,dd2=scaleseparation(H1K1,H2K2,value-mean(value);niter=3);
# Out:
# MethodError: no method matching -(::Vector{Float64}, ::Float64)
# For element-wise subtraction, use broadcasting with dot syntax: array .- scalar
# The function `-` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   -(::SciMLOperators.IdentityOperator, ::Number)
#    @ SciMLOperators ~/.julia/packages/SciMLOperators/KVzmP/src/basic.jl:386
#   -(::ChainRulesCore.ZeroTangent, ::Any)
#    @ ChainRulesCore ~/.julia/packages/ChainRulesCore/6Pucz/src/tangent_arithmetic.jl:101
#   -(::Any, ::ChainRulesCore.NotImplemented)
#    @ ChainRulesCore ~/.julia/packages/ChainRulesCore/6Pucz/src/tangent_arithmetic.jl:50
#   ...
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[18]:1

# %%
figure
pcolor(yit[1,:,:],zit[1,:,:],mean(value)+fdet[1,:,:]),colorbar()
figure()
scatter(coordinatesfordetrending[2],coordinatesfordetrending[3],s=2,c=value,vmin=17,vmax=18.4);colorbar()
# Out:
# UndefVarError: `figure` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.

# %%
figure()
pcolor(xi[:,:,1],yi[:,:,1],mean(value)+fsur[:,:,1]),colorbar()
# Out:
# UndefVarError: `figure` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[20]:1

# %%
figure()
pcolor(xi[:,:,1],yi[:,:,1],fsurori[:,:,1]-fsur[:,:,1]),colorbar()
title("Direct analysis minus detrended analysis")
# Out:
# UndefVarError: `figure` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[21]:1

# %%
plot((fdet[1,10,:]))
# Out:
# UndefVarError: `fdet` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[22]:1

# %%
fsurs=deepcopy(fsur)+mean(value);
# Out:
# UndefVarError: `fsur` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[23]:1

# %%
figure()
pcolor(xi[:,30,1:15],-zi[:,30,1:15],fsurs[:,30,1:15]),colorbar()
title("Salinity section")
# Out:
# UndefVarError: `figure` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[24]:1

# %% [markdown]
# ## Now temperature

# %%
value,lon,lat,depth,timeval,ids = DIVAnd.loadbigfile("Temperature.bigfile")
@show size(value)

lowestdata=4
highestdata=27
sel=(value.>lowestdata) .& (value.<highestdata).& .~((lon.>34.75) .& (lat.>45.10)) .& 
.~((lon.<29.5) .& (lat.<41.125)) .& (depth.<deepestdata) .& (timeval .> DateTime(Date(1950)))

scatter(lon,lat,s=2,c=value,vmin=lowestdata,vmax=highestdata);colorbar()

@show(size(value))

value=value[sel]
lon=lon[sel]
lat=lat[sel]
depth=depth[sel]
timeval=timeval[sel]
ids=ids[sel]

@show(size(value))
figure()

scatter(lon,lat,s=2,c=value,vmin=lowestdata,vmax=highestdata);colorbar()
title("with data selection")
# Out:
# [ Info: Loading data from 'big file' Temperature.bigfile
# SystemError: opening file "Temperature.bigfile": No such file or directory
#
# Stacktrace:
#  [1] systemerror(p::String, errno::Int32; extrainfo::Nothing)
#    @ Base ./error.jl:176
#  [2] systemerror
#    @ ./error.jl:175 [inlined]
#  [3] open(fname::String; lock::Bool, read::Bool, write::Nothing, create::Nothing, truncate::Nothing, append::Nothing)
#    @ Base ./iostream.jl:295
#  [4] open
#    @ ./iostream.jl:277 [inlined]
#  [5] open(fname::String, mode::String; lock::Bool)
#    @ Base ./iostream.jl:358
#  [6] open
#    @ ./iostream.jl:357 [inlined]
#  [7] loadbigfile(fname::String)
#    @ DIVAnd ~/.julia/packages/DIVAnd/4UymR/src/load_obs.jl:11
#  [8] top-level scope
#    @ In[25]:1

# %%
coordinatesfordetrending=(depth,dayinyear.(timeval),daysince1900.(timeval));
#tmin,tmax=extrema(daysince1900.(timeval))
maskt,(pmt,pnt,pot),(xit,yit,zit) = DIVAnd.DIVAnd_rectdom(depthr,0:10:365,tmin:150:tmax);

# %%
function H1K1t(data)
    K1d,s=DIVAnd.DIVAndrun(maskt,(pmt,pnt,pot),(xit,yit,zit),coordinatesfordetrending,data,(lent1,lent2,lent3),epsilon2*rdiag;moddim=[0,365,0]);
    #K1d,s=DIVAndrun(mask[1],pm[1],xi[1],x,data,len[1],epsilon2)    
    return K1d,data-DIVAnd_residual(s,K1d)
end
function H2K2t(data)
    K2d,s=DIVAnd.DIVAndrun(mask,(pm,pn,po),(xi,yi,zi),(lon,lat,depth),data,(lenx,leny,lenz),epsilon2*rdiag);
    #K1d,s=DIVAndrun(mask[1],pm[1],xi[1],x,data,len[1],epsilon2)    
    return K2d,data-DIVAnd_residual(s,K2d)
end
# Out:
# H2K2t (generic function with 1 method)

# %%
rdiag=1.0./DIVAnd.weight_RtimesOne((lon,lat,depth),(0.03,0.03,10));
mean(rdiag)




fdet,bidon=H1K1t(value-mean(value));

pcolor(yit[1,:,:],zit[1,:,:],mean(value)+fdet[1,:,:]),colorbar()
figure()
scatter(coordinatesfordetrending[2],coordinatesfordetrending[3],s=2,c=value,vmin=6,vmax=22);colorbar()

fsur,bidon=H2K2t(value-mean(value))
fsurori=fsur;

figure()
pcolor(xi[:,:,1],yi[:,:,1],mean(value)+fsur[:,:,1]),colorbar()
figure()
scatter(lon,lat,s=2,c=value,vmin=6,vmax=22);colorbar()
# Out:
# [ Info: Computing weights using 1 CPU thread(s)
# MethodError: no method matching -(::Vector{Float64}, ::Float64)
# For element-wise subtraction, use broadcasting with dot syntax: array .- scalar
# The function `-` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   -(::SciMLOperators.IdentityOperator, ::Number)
#    @ SciMLOperators ~/.julia/packages/SciMLOperators/KVzmP/src/basic.jl:386
#   -(::ChainRulesCore.ZeroTangent, ::Any)
#    @ ChainRulesCore ~/.julia/packages/ChainRulesCore/6Pucz/src/tangent_arithmetic.jl:101
#   -(::Any, ::ChainRulesCore.NotImplemented)
#    @ ChainRulesCore ~/.julia/packages/ChainRulesCore/6Pucz/src/tangent_arithmetic.jl:50
#   ...
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[28]:2

# %%
fdett,dd1,fsurt,dd2=scaleseparation(H1K1t,H2K2t,value-mean(value);niter=3);
# Out:
# MethodError: no method matching -(::Vector{Float64}, ::Float64)
# For element-wise subtraction, use broadcasting with dot syntax: array .- scalar
# The function `-` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   -(::SciMLOperators.IdentityOperator, ::Number)
#    @ SciMLOperators ~/.julia/packages/SciMLOperators/KVzmP/src/basic.jl:386
#   -(::ChainRulesCore.ZeroTangent, ::Any)
#    @ ChainRulesCore ~/.julia/packages/ChainRulesCore/6Pucz/src/tangent_arithmetic.jl:101
#   -(::Any, ::ChainRulesCore.NotImplemented)
#    @ ChainRulesCore ~/.julia/packages/ChainRulesCore/6Pucz/src/tangent_arithmetic.jl:50
#   ...
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[29]:1

# %%
fsurt=fsurt+mean(value);
# Out:
# UndefVarError: `fsurt` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[30]:1

# %%
figure()
pcolor(xi[:,:,1],yi[:,:,1],fsurt[:,:,1]),colorbar()
# Out:
# UndefVarError: `figure` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[31]:1

# %%
pcolor(yi[80,:,1:15],-zi[80,:,1:15],fsurt[80,:,1:15]),colorbar()
# Out:
# UndefVarError: `pcolor` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[32]:1

# %% [markdown]
# ## Geostrophic calculation using level of no motion

# %%
FN=zeros(size(depthr)[1])
dens=density.(fsurs,fsurt,0)-1025

for iz=1:size(depthr)[1]
    

    velocities,eta,Vflux=geostrophy(mask,dens,(pm,pn,po),(xi,yi,zi);znomotion=iz);
eta=eta-mean(eta);
    FN[iz]=mean(Vflux[1].^2)+mean(Vflux[2].^2)
end
figure

plot(FN)
title("Barotropic budget for different levels of no motion")
# Out:
# UndefVarError: `density` not defined in `Main`
# Hint: It looks like two or more modules export different bindings with this name, resulting in ambiguity. Try explicitly importing it from a particular module, or qualifying the name with the module it should come from.
# Hint: a global variable of this name also exists in Makie.
# Hint: a global variable of this name also exists in CairoMakie.
# Hint: a global variable of this name also exists in GeoMakie.
# Hint: a global variable of this name also exists in PhysOcean.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[33]:2

# %% [markdown]
# ### Just an arbitrary level, to be corrected later

# %%
iz=indmin(FN)
@show iz

iz=15

velocities,eta,Vflux=geostrophy(mask,dens,(pm,pn,po),(xi,yi,zi);znomotion=iz);
eta=eta-mean(eta);



eta=DIVAnd_filter3(eta,NaN,10)



velocities,eta,Vflux=geostrophy(mask,dens,(pm,pn,po),(xi,yi,zi);ssh=eta)
# Out:
# UndefVarError: `indmin` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[34]:1

# %%
contourf(xi[:,:,1],yi[:,:,1],eta+0*fsurt[:,:,1],20);colorbar()
# Out:
# UndefVarError: `eta` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
# Hint: a global variable of this name may be made accessible by importing SpecialFunctions in the current active module Main
#
# Stacktrace:
#  [1] top-level scope
#    @ In[35]:1

# %% [markdown]
# Geostrophic calculationwith level of not motion provides non-zero global fluxes

# %%
mean(Vflux[1].^2)+mean(Vflux[2].^2)
# Out:
# UndefVarError: `Vflux` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[36]:1

# %% [markdown]
# Try the correction term

# %%
x = rand(1);
y = rand(1);
f = x

h=deepestpoint(mask,zi)
len=1
epsilon2=10000
rfluxes=0.000001

#Need to scale fluxes by f/g
gsf=(earthgravity.(yi)./coriolisfrequency.(yi))[:,:,1]
fi,s=DIVAndrun(mask[:,:,1],(pm[:,:,1],pn[:,:,1]),(xi[:,:,1],yi[:,:,1]),(x,y),f,len,epsilon2;topographyforfluxes=(gsf.*h,gsf.*h),fluxes=Vflux,epsfluxes=rfluxes,alphabc=1,alpha=[1, 0, 1]);
# Out:
# UndefVarError: `Vflux` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[37]:11

# %%
fim=deepcopy(fi);
# Out:
# UndefVarError: `fi` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[38]:1

# %%
fi[isnan.(fi)]=0
# Out:
# UndefVarError: `fi` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[39]:1

# %%
velafter,etaafter,Vfluxafter=geostrophy(mask,dens,(pm,pn,po),(xi,yi,zi);ssh=eta+fi);
# Out:
# UndefVarError: `eta` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
# Hint: a global variable of this name may be made accessible by importing SpecialFunctions in the current active module Main
#
# Stacktrace:
#  [1] top-level scope
#    @ In[40]:1

# %%
contourf(xi[:,:,1],yi[:,:,1],etaafter+0*fim,20);colorbar()
# Out:
# UndefVarError: `etaafter` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[41]:1

# %% [markdown]
# Now much lower global fluxes

# %%
mean(Vfluxafter[1].^2)+mean(Vfluxafter[2].^2)
# Out:
# UndefVarError: `Vfluxafter` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[42]:1

# %%
pcolor(yi[20,:,15:25],-zi[20,:,15:25],fsurs[20,:,15:25]),colorbar()
# Out:
# UndefVarError: `pcolor` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[43]:1
